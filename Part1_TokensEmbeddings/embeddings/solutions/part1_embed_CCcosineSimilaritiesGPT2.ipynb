# %% [markdown]
# |<h2>Course:</h2>|<h1><a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">A deep understanding of AI language model mechanisms</a></h1>|
# |-|:-:|
# |<h2>Part 1:</h2>|<h1>Tokenizations and embeddings<h1>|
# |<h2>Section:</h2>|<h1>Embedding spaces<h1>|
# |<h2>Lecture:</h2>|<h1><b>CodeChallenge: GPT2 cosine similarities<b></h1>|
#
# <br>
#
# <h5><b>Teacher:</b> Mike X Cohen, <a href="https://sincxpress.com" target="_blank">sincxpress.com</a></h5>
# <h5><b>Course URL:</b> <a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">udemy.com/course/dullms_x/?couponCode=202508</a></h5>
# <i>Using the code without the course may lead to confusion or errors.</i>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %% [markdown]
# # Import GPT-2 model and extract its embedding matrix

# %%
from transformers import GPT2Model,GPT2Tokenizer

# pretrained GPT-2 model and tokenizer
# gpt2 = GPT2Model.from_pretrained('gpt2')
gpt2 = GPT2Model.from_pretrained('/home/meysam/Gpt2/model.safetensors', config='/home/meysam/Gpt2/config.json')
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 # pretrained GPT-2 model and tokenizer
#       4 # gpt2 = GPT2Model.from_pretrained('gpt2')
#       5 gpt2 = GPT2Model.from_pretrained('/home/meysam/Gpt2/model.safetensors', config='/home/meysam/Gpt2/config.json')
# ----> 6 tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
#
# File ~/anaconda3/lib/python3.13/site-packages/transformers/tokenization_utils_base.py:1643, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    1641 if "tokenizer_file" in vocab_files:
#    1642     fast_tokenizer_file = FULL_TOKENIZER_FILE
# -> 1643     resolved_config_file = cached_file(
#    1644         pretrained_model_name_or_path,
#    1645         TOKENIZER_CONFIG_FILE,
#    1646         cache_dir=cache_dir,
#    1647         force_download=force_download,
#    1648         proxies=proxies,
#    1649         token=token,
#    1650         revision=revision,
#    1651         local_files_only=local_files_only,
#    1652         subfolder=subfolder,
#    1653         user_agent=user_agent,
#    1654         _raise_exceptions_for_missing_entries=False,
#    1655         _commit_hash=commit_hash,
#    1656     )
#    1657     if resolved_config_file is not None:
#    1658         with open(resolved_config_file, encoding="utf-8") as reader:
#
# File ~/anaconda3/lib/python3.13/site-packages/transformers/utils/hub.py:293, in cached_file(path_or_repo_id, filename, **kwargs)
#     238 def cached_file(
#     239     path_or_repo_id: str | os.PathLike,
#     240     filename: str,
#     241     **kwargs,
#     242 ) -> str | None:
#     243     """
#     244     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     245
#    (...)
#     291     ```
#     292     """
# --> 293     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     294     file = file[0] if file is not None else file
#     295     return file
#
# File ~/anaconda3/lib/python3.13/site-packages/transformers/utils/hub.py:437, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     434 try:
#     435     if len(full_filenames) == 1:
#     436         # This is slightly better for only 1 file
# --> 437         hf_hub_download(
#     438             path_or_repo_id,
#     439             filenames[0],
#     440             subfolder=None if len(subfolder) == 0 else subfolder,
#     441             repo_type=repo_type,
#     442             revision=revision,
#     443             cache_dir=cache_dir,
#     444             user_agent=user_agent,
#     445             force_download=force_download,
#     446             proxies=proxies,
#     447             token=token,
#     448             local_files_only=local_files_only,
#     449             tqdm_class=tqdm_class,
#     450         )
#     451     else:
#     452         snapshot_download(
#     453             path_or_repo_id,
#     454             allow_patterns=full_filenames,
#    (...)
#     463             tqdm_class=tqdm_class,
#     464         )
#
# File ~/anaconda3/lib/python3.13/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.13/site-packages/huggingface_hub/file_download.py:1015, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     994     return _hf_hub_download_to_local_dir(
#     995         # Destination
#     996         local_dir=local_dir,
#    (...)
#    1012         dry_run=dry_run,
#    1013     )
#    1014 else:
# -> 1015     return _hf_hub_download_to_cache_dir(
#    1016         # Destination
#    1017         cache_dir=cache_dir,
#    1018         # File info
#    1019         repo_id=repo_id,
#    1020         filename=filename,
#    1021         repo_type=repo_type,
#    1022         revision=revision,
#    1023         # HTTP info
#    1024         endpoint=endpoint,
#    1025         etag_timeout=etag_timeout,
#    1026         headers=hf_headers,
#    1027         token=token,
#    1028         # Additional options
#    1029         local_files_only=local_files_only,
#    1030         force_download=force_download,
#    1031         tqdm_class=tqdm_class,
#    1032         dry_run=dry_run,
#    1033     )
#
# File ~/anaconda3/lib/python3.13/site-packages/huggingface_hub/file_download.py:1090, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1086             return pointer_path
#    1088 # Try to get metadata (etag, commit_hash, url, size) from the server.
#    1089 # If we can't, a HEAD request error is returned.
# -> 1090 (url_to_download, etag, commit_hash, expected_size, xet_file_data, head_call_error) = _get_metadata_or_catch_error(
#    1091     repo_id=repo_id,
#    1092     filename=filename,
#    1093     repo_type=repo_type,
#    1094     revision=revision,
#    1095     endpoint=endpoint,
#    1096     etag_timeout=etag_timeout,
#    1097     headers=headers,
#    1098     token=token,
#    1099     local_files_only=local_files_only,
#    1100     storage_folder=storage_folder,
#    1101     relative_filename=relative_filename,
#    1102 )
#    1104 # etag can be None for several reasons:
#    1105 # 1. we passed local_files_only.
#    1106 # 2. we don't have a connection
#    (...)
#    1112 # If the specified revision is a commit hash, look inside "snapshots".
#    1113 # If the specified revision is a branch or tag, look inside "refs".
#    1114 if head_call_error is not None:
#    1115     # Couldn't make a HEAD call => let's try to find a local file
#
# File ~/anaconda3/lib/python3.13/site-packages/huggingface_hub/file_download.py:1690, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder, retry_on_errors)
#    1688 try:
#    1689     try:
# -> 1690         metadata = get_hf_file_metadata(
#    1691             url=url,
#    1692             timeout=etag_timeout,
#    1693             headers=headers,
#    1694             token=token,
#    1695             endpoint=endpoint,
#    1696             retry_on_errors=retry_on_errors,
#    1697         )
#    1698     except RemoteEntryNotFoundError as http_error:
#    1699         if storage_folder is not None and relative_filename is not None:
#    1700             # Cache the non-existence of the file
#
# File ~/anaconda3/lib/python3.13/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.13/site-packages/huggingface_hub/file_download.py:1612, in get_hf_file_metadata(url, token, timeout, library_name, library_version, user_agent, headers, endpoint, retry_on_errors)
#    1609 hf_headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to know the real size of the file
#    1611 # Retrieve metadata
# -> 1612 response = _httpx_follow_relative_redirects_with_backoff(
#    1613     method="HEAD", url=url, headers=hf_headers, timeout=timeout, retry_on_errors=retry_on_errors
#    1614 )
#    1615 hf_raise_for_status(response)
#    1617 # Return
#
# File ~/anaconda3/lib/python3.13/site-packages/huggingface_hub/utils/_http.py:685, in _httpx_follow_relative_redirects_with_backoff(method, url, retry_on_errors, **httpx_kwargs)
#     680 no_retry_kwargs: dict[str, Any] = (
#     681     {} if retry_on_errors else {"retry_on_exceptions": (), "retry_on_status_codes": ()}
#     682 )
#     684 while True:
# --> 685     response = http_backoff(
#     686         method=method,
#     687         url=url,
#     688         **httpx_kwargs,
#     689         follow_redirects=False,
#     690         **no_retry_kwargs,
#     691     )
#     692     hf_raise_for_status(response)
#     694     # Check if response is a relative redirect
#
# File ~/anaconda3/lib/python3.13/site-packages/huggingface_hub/utils/_http.py:559, in http_backoff(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, **kwargs)
#     494 def http_backoff(
#     495     method: HTTP_METHOD_T,
#     496     url: str,
#    (...)
#     503     **kwargs,
#     504 ) -> httpx.Response:
#     505     """Wrapper around httpx to retry calls on an endpoint, with exponential backoff.
#     506
#     507     Endpoint call is retried on exceptions (ex: connection timeout, proxy error,...)
#    (...)
#     557     > issue on [Github](https://github.com/huggingface/huggingface_hub).
#     558     """
# --> 559     return next(
#     560         _http_backoff_base(
#     561             method=method,
#     562             url=url,
#     563             max_retries=max_retries,
#     564             base_wait_time=base_wait_time,
#     565             max_wait_time=max_wait_time,
#     566             retry_on_exceptions=retry_on_exceptions,
#     567             retry_on_status_codes=retry_on_status_codes,
#     568             stream=False,
#     569             **kwargs,
#     570         )
#     571     )
#
# File ~/anaconda3/lib/python3.13/site-packages/huggingface_hub/utils/_http.py:467, in _http_backoff_base(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, stream, **kwargs)
#     465             return
#     466 else:
# --> 467     response = client.request(method=method, url=url, **kwargs)
#     468     if not _should_retry(response):
#     469         yield response
#
# File ~/anaconda3/lib/python3.13/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)
#     823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/anaconda3/lib/python3.13/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/anaconda3/lib/python3.13/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/anaconda3/lib/python3.13/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/anaconda3/lib/python3.13/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/anaconda3/lib/python3.13/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/anaconda3/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/anaconda3/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/anaconda3/lib/python3.13/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      99 except BaseException as exc:
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/anaconda3/lib/python3.13/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      76 with self._request_lock:
#      77     if self._connection is None:
# ---> 78         stream = self._connect(request)
#      80         ssl_object = stream.get_extra_info("ssl_object")
#      81         http2_negotiated = (
#      82             ssl_object is not None
#      83             and ssl_object.selected_alpn_protocol() == "h2"
#      84         )
#
# File ~/anaconda3/lib/python3.13/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     116     kwargs = {
#     117         "host": self._origin.host.decode("ascii"),
#     118         "port": self._origin.port,
#    (...)
#     121         "socket_options": self._socket_options,
#     122     }
#     123     with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124         stream = self._network_backend.connect_tcp(**kwargs)
#     125         trace.return_value = stream
#     126 else:
#
# File ~/anaconda3/lib/python3.13/site-packages/httpcore/_backends/sync.py:208, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
#     207 with map_exceptions(exc_map):
# --> 208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#     213     for option in socket_options:
#     214         sock.setsockopt(*option)  # pragma: no cover
#
# File ~/anaconda3/lib/python3.13/socket.py:849, in create_connection(address, timeout, source_address, all_errors)
#     847 if source_address:
#     848     sock.bind(source_address)
# --> 849 sock.connect(sa)
#     850 # Break explicitly a reference cycle
#     851 exceptions.clear()
#
# KeyboardInterrupt:

# %%
# get the Word Token Embeddings matrix
embeddings = gpt2.wte.weight.detach().numpy()

# %% [markdown]
# # Exercise 1: The cosmic banana

# %%
# words of interest
word1 = 'banana'
word2 = 'apple'
word3 = 'cosmic'

# decomposition
for w in [word1,word2,word3]:
  t = tokenizer.encode(w)
  print(f'"{w}" comprises {len(t)} tokens:\n   {[tokenizer.decode(i) for i in t]}\n')

# %%
# setup the figure subplot geometry
fig = plt.figure(figsize=(10,7))
gs = GridSpec(2,2)
ax0 = fig.add_subplot(gs[0,:])
ax1 = fig.add_subplot(gs[1,0])
ax2 = fig.add_subplot(gs[1,1])


# plot the embeddings by dimension
colors = 'krb'
linestyles = ['-','--','-.',':']
for idx,word in enumerate([word1,word2,word3]):
  wordidx = tokenizer.encode(word)
  for j in range(len(wordidx)):
    ax0.plot(embeddings[wordidx[j],:],linestyle=linestyles[j],color=colors[idx],label=tokenizer.decode(wordidx[j]))

ax0.set(xlabel='Dimension',title='Embeddings',xlim=[-1,embeddings.shape[1]+1])
ax0.legend()



# cosine similarity between 'ban' and 'ana'
v1 = embeddings[tokenizer.encode('ban')]
v2 = embeddings[tokenizer.encode('ana')]
cossim = np.sum(v1*v2)/(np.linalg.norm(v1)*np.linalg.norm(v2))

# plot the embeddings by each other
ax1.plot(v1,v2,'ko',markerfacecolor=[.7,.7,.7,.6])
ax1.set(xlim=[-.8,.8],ylim=[-.8,.8],xlabel='"ban" embedding',ylabel='"ana" embedding',
        title=f'Cosine similarity = {cossim:.3f}')



# plot the "cos" for two endings
for s in ['mic','ine']:

  # cosine similarity
  v1 = embeddings[tokenizer.encode('cos')].squeeze()
  v2 = embeddings[tokenizer.encode(s)].squeeze()
  cossim = np.sum(v1*v2) / (np.linalg.norm(v1)*np.linalg.norm(v2))

  # plot
  ax2.plot(v1,v2,marker=f'${s[0]}$',linestyle='none',alpha=.6,label=f'cos-{s} ($s_c$  = {cossim:.3f})')

ax2.legend(fontsize=10)
ax2.set(xlim=[-.8,.8],ylim=[-.8,.8],xlabel='"cos" embedding',ylabel='"mic" or "ine" embedding')


# final touches
plt.tight_layout()
plt.show()

# %% [markdown]
# # Exercise 2: Find tokens with similar embeddings

# %%
# get seed index and embedding vector
seed = tokenizer.encode('Mike')
seedvect = embeddings[seed].squeeze()
seedvectNorm = np.linalg.norm(seedvect)

# calculate cosine similarity to all other tokens in a for-loop
cossims = np.zeros(embeddings.shape[0])
for idx,v in enumerate(embeddings):
  cossims[idx] = np.sum(seedvect*v) / (seedvectNorm*np.linalg.norm(v))



# and visualize
plt.figure(figsize=(10,4))
plt.plot(cossims,'k.',alpha=.6,markerfacecolor='w')
plt.gca().set(xlim=[-5,len(cossims)+5],xlabel='Token index',ylabel='Cosine similarity',
              title='Cosine similarity to "Mike"')


# top 20 largest cosine-similarities
top20 = np.argsort(cossims)[-20:]
for i in top20:
  plt.plot(i,cossims[i],'ms',markersize=4,alpha=.6)

plt.show()

# %%
# tokens closest to "Mike"
for n in top20[::-1]:
  print(f'"{tokenizer.decode(n)}" with cosine similarity {cossims[n]:.3f}')

# %% [markdown]
# # Exercise 3: One-to-all cosine similarity via linear algebra

# %%
# normalize entire embedding matrix (in a new variable!)
Enorm = embeddings / np.linalg.norm(embeddings,axis=1,keepdims=True)

# cosine similarity matrices
cossims2 = Enorm[seed] @ Enorm.T

# %%
print(f'Size of for-loop version:   {cossims.shape}')
print(f'Size of vectorized version: {cossims2.shape}')

# remove singleton dimension
cossims2 = np.squeeze(cossims2)

# inspect again
print('\n** After squeezing:')
print(f'Size of for-loop version:   {cossims.shape}')
print(f'Size of vectorized version: {cossims2.shape}')

# %%
plt.figure(figsize=(10,4))
plt.plot(range(0,len(cossims),100),cossims[::100],'o',label='for-loop')
plt.plot(range(0,len(cossims),100),cossims2[::100],'+',label='vectorized')

plt.legend()
plt.gca().set(xlabel='Token idx (plotting every 100)',ylabel='Cossine similarity',title=f'Correlation = {np.corrcoef(cossims,cossims2)[0,1]:.3f}')
plt.show()
