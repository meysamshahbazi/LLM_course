# %% [markdown]
# |<h2>Course:</h2>|<h1><a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">A deep understanding of AI language model mechanisms</a></h1>|
# |-|:-:|
# |<h2>Part 1:</h2>|<h1>Tokenizations and embeddings<h1>|
# |<h2>Section:</h2>|<h1>Words to tokens to numbers<h1>|
# |<h2>Lecture:</h2>|<h1><b>CodeChallenge HELPER: Create your algorithmic rapper name :)<b></h1>|
#
# <br>
#
# <h5><b>Teacher:</b> Mike X Cohen, <a href="https://sincxpress.com" target="_blank">sincxpress.com</a></h5>
# <h5><b>Course URL:</b> <a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">udemy.com/course/dullms_x/?couponCode=202508</a></h5>
# <i>Using the code without the course may lead to confusion or errors.</i>

# %%
import numpy as np
import re

# GPT-4's tokenizer
# !pip install tiktoken
import tiktoken
tokenizer = tiktoken.get_encoding('cl100k_base')
# Out:
# Requirement already satisfied: tiktoken in /home/meysam/anaconda3/lib/python3.13/site-packages (0.13.0)
# Requirement already satisfied: regex in /home/meysam/anaconda3/lib/python3.13/site-packages (from tiktoken) (2025.9.1)
# Requirement already satisfied: requests in /home/meysam/anaconda3/lib/python3.13/site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/meysam/anaconda3/lib/python3.13/site-packages (from requests->tiktoken) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/meysam/anaconda3/lib/python3.13/site-packages (from requests->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/meysam/anaconda3/lib/python3.13/site-packages (from requests->tiktoken) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/meysam/anaconda3/lib/python3.13/site-packages (from requests->tiktoken) (2025.11.12)

# %%
first_name = 'meysam'
last_name = 'shahbazi'
fav_color = 'red'

text = ' '.join([first_name, last_name, fav_color])
text
# Out:
# 'meysam shahbazi red'

# %%
idx = tokenizer.encode(text)
# sort
idx.sort()

# %%
# a function to find "non-normal" text (will return false if there are non-alphanumeric characters)
def not_normal(token_str):
  pattern = re.compile(r'^[A-Za-z0-9\s]+$')
  return not bool(pattern.fullmatch(token_str))

# %%
# part 1: first letter of first name -1
part1 = tokenizer.encode(first_name[0])[0] -1
while not_normal(tokenizer.decode([part1])):
  part1 += 1


# part 2: last letter of the last name +1
part2 = tokenizer.encode(last_name[-1])[0] -1
while not_normal(tokenizer.decode([part2])):
  part2 + 1


# part 3: last/first + average of middle
part3 = int(idx[0]/idx[-1] + np.mean(idx[1:-1]))

rappername = [part1, part2, part3]
print(f'My rapper name is "{tokenizer.decode(rappername)}"')
# Out:
# My rapper name is "lh most"
